# %%
age=25
type(age)
# Out:
# int

# %%
height=5.11
print(height, type(height))
# Out:
# 5.11 <class 'float'>

# %%
name="ayushi"
print(name, type(name))
# Out:
# ayushi <class 'str'>

# %%
is_true=True
type(is_true)
# Out:
# bool

# %%
is_true = bool()

print(is_true, type(is_true)) #default is False
# Out:
# False <class 'bool'>

# %%
a=10
b=10

print(a==b)
type(a==b)
# Out:
# True
# bool

# %%
result="hello" + 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result="hello" + 5
#
# TypeError: can only concatenate str (not "int") to str

# %%
result="hello" + str(5)
print(result)
# Out:
# hello5
