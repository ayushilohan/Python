# %%
a=10
b=15
add = a+b 
sub = a-b
mul = a*b
div = int(a/b)
floor_div = a//b
mod = a%b #remainder
expo = a**7
print(add, sub, mul, div, floor_div, mod, expo)
# Out:
# 25 -5 150 0 0 10 10000000

# %%
21/5
# Out:
# 4.2

# %%
21//5
# Out:
# 4

# %%
# comparison operators
# ==

a=10
b=10

result = (a==b)
print(result)
# Out:
# True

# %%
str1 = "ayushi"
str2 = "ayushi"

str1 == str2
# Out:
# True

# %%
# not equal to

str1!=str2
# Out:
# False

# %%
str3 = "ayushi"
str4 = "Ayushi"

str3!=str4
# Out:
# True

# %%
num1=45
num2=55

#num1>num2
num1<num2
# Out:
# True

# %%
num1 = 40
num2 = 45

num1>=num2
# Out:
# False

# %%
#logical operator
# And, Not, OR

x=False
y=True
result = x and y # and or
print(result)

c=True
not c
# Out:
# False
# False
